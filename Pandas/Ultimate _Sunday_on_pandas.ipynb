# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##### 2d consting of data is called the dataframe

# %% [markdown]
# ### Creating the dataframe : (used by the 2d List)

# %%
students_data = [
    [100,80,10],
    [300,50,21],
    [400,30,15],
    [444,21,6]
]
students= pd.DataFrame(students_data,columns=["iq","marks","Package"])

# %%
students
# Out:
#     iq  marks  Package
# 0  100     80       10
# 1  300     50       21
# 2  400     30       15
# 3  444     21        6

# %%
## Using the Read_csv
movies = pd.read_csv('movies.csv') 
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl = pd.read_csv('ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# ### Importand Attributes

# %%
# Shape
movies.shape
# Out:
# (1629, 18)

# %%
ipl.shape
# Out:
# (950, 20)

# %%
# dtypes
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
# index
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
#columns
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
#values - it wil give al the values of the data
movies.values
# Out:
# array([['Uri: The Surgical Strike', 'tt8291224',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/3/3b/URI_-_New_poster.jpg/220px-URI_-_New_poster.jpg',
#         ...,
#         'Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Gautam|Kirti Kulhari|Rajit Kapoor|Ivan Rodrigues|Manasi Parekh|Swaroop Sampat|Riva Arora|Yogesh Soman|Fareed Ahmed|Akashdeep Arora|Kallol Banerjee|',
#         '4 wins', '11 January 2019 (USA)'],
#        ['Battalion 609', 'tt9472208', nan, ...,
#         'Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elena Kazan|Vishwas Kini|Major Kishore|Jashn Kohli|Rammy C. Pandey|Manish Sharma|Sparsh Sharma|Farnaz Shetty|Vikas Shrivastav|Chandraprakash Thakur|Brajesh Tiwari|',
#         nan, '11 January 2019 (India)'],
#        ['The Accidental Prime Minister (film)', 'tt6986710',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/a/a1/The_Accidental_Prime_Minister_film.jpg/220px-The_Accidental_Prime_Minister_film.jpg',
#         ...,
# ...

# %%
# head and tail  - first and last 5 values
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
# also we can use the head and tail for our necessaty values
movies.tail(10)   #these are the last 10 values of the table
# Out:
#                             title_x     imdb_id  \
# 1619              Pyaar Zindagi Hai   tt0847758
# 1620       Yeh Raaste Hain Pyaar Ke   tt0292740
# 1621                        Tum Bin   tt0290326
# 1622  Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1623                       Zubeidaa   tt0255713
# 1624          Tera Mera Saath Rahen   tt0301250
# 1625           Yeh Zindagi Ka Safar   tt0298607
# 1626                Sabse Bada Sukh   tt0069204
# 1627                          Daaka  tt10833860
# 1628                       Humsafar   tt2403201
#
#                                             poster_path  \
# 1619  https://upload.wikimedia.org/wikipedia/en/5/5e...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# 1621  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1624  https://upload.wikimedia.org/wikipedia/en/2/2b...
# ...

# %%
# Sample - like in head- tail they give the top and bottom of the data , but we want mix like the middile data of like average students
ipl.sample(4) # randomise the any 4 values or datframe
# Out:
#           ID       City        Date Season MatchNumber  \
# 547   729287        NaN  2014-04-19   2014           5
# 699   548308     Mumbai  2012-04-06   2012           3
# 331  1082633  Bangalore  2017-05-05   2017          43
# 482   829725       Pune  2015-04-15   2015          10
#
#                            Team1             Team2  \
# 547  Royal Challengers Bangalore    Mumbai Indians
# 699               Mumbai Indians     Pune Warriors
# 331  Royal Challengers Bangalore   Kings XI Punjab
# 482              Kings XI Punjab  Delhi Daredevils
#
#                                        Venue                   TossWinner  \
# 547      Dubai International Cricket Stadium  Royal Challengers Bangalore
# 699                         Wankhede Stadium               Mumbai Indians
# 331                    M Chinnaswamy Stadium  Royal Challengers Bangalore
# 482  Maharashtra Cricket Association Stadium              Kings XI Punjab
#
# ...

# %%
# info    - it give the information about the how is the data , may be the valuses are missing of getiing out of the result
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
#describe - it will give the mathematical summary
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
#isnull
movies.isnull()
# Out:
#       title_x  imdb_id  poster_path  wiki_link  title_y  original_title  \
# 0       False    False        False      False    False           False
# 1       False    False         True      False    False           False
# 2       False    False        False      False    False           False
# 3       False    False        False      False    False           False
# 4       False    False         True      False    False           False
# ...       ...      ...          ...        ...      ...             ...
# 1624    False    False        False      False    False           False
# 1625    False    False        False      False    False           False
# 1626    False    False         True      False    False           False
# 1627    False    False        False      False    False           False
# 1628    False    False        False      False    False           False
#
#       is_adult  year_of_release  runtime  genres  imdb_rating  imdb_votes  \
# ...

# %%
# or for consise data
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
# duplicated - data (tells which is duplocate)
movies.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627    False
# 1628    False
# Length: 1629, dtype: bool

# %%
#same here using the sum 
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
#rename -it rename the columns
students.rename(columns={'iq':'talent','marks':'number'})
# Out:
#    talent  number  Package
# 0     100      80       10
# 1     300      50       21
# 2     400      30       15
# 3     444      21        6

# %%
# math

# %%
#sum
students
# Out:
#     iq  marks  Package
# 0  100     80       10
# 1  300     50       21
# 2  400     30       15
# 3  444     21        6

# %%
students.sum()    #it will add all the columns and give the result
# Out:
# iq         1244
# marks       181
# Package      52
# dtype: int64

# %%
students.sum(axis=1) #row wise sum
# Out:
# 0    190
# 1    371
# 2    445
# 3    471
# dtype: int64

# %%
students.mean()
# Out:
# iq         311.00
# marks       45.25
# Package     13.00
# dtype: float64

# %%
students.max()
# Out:
# iq         444
# marks       80
# Package     21
# dtype: int64

# %%
#single col - it will give the single column only
movies['title_x']
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
ipl['City']
# Out:
# 0       Ahmedabad
# 1       Ahmedabad
# 2         Kolkata
# 3         Kolkata
# 4          Mumbai
#           ...
# 945       Kolkata
# 946        Mumbai
# 947         Delhi
# 948    Chandigarh
# 949     Bangalore
# Name: City, Length: 950, dtype: object

# %%
## Multiple Columnts - here we gives in[list of the wants]
movies[['title_x' , 'year_of_release', 'actors']]
# Out:
#                                    title_x  year_of_release  \
# 0                 Uri: The Surgical Strike             2019
# 1                            Battalion 609             2019
# 2     The Accidental Prime Minister (film)             2019
# 3                          Why Cheat India             2019
# 4                          Evening Shadows             2018
# ...                                    ...              ...
# 1624                 Tera Mera Saath Rahen             2001
# 1625                  Yeh Zindagi Ka Safar             2001
# 1626                       Sabse Bada Sukh             2018
# 1627                                 Daaka             2019
# 1628                              Humsafar             2011
#
#                                                  actors
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# ...

# %%
ipl[['City','Venue','Margin']]
# Out:
#            City                                       Venue  Margin
# 0     Ahmedabad            Narendra Modi Stadium, Ahmedabad     7.0
# 1     Ahmedabad            Narendra Modi Stadium, Ahmedabad     7.0
# 2       Kolkata                       Eden Gardens, Kolkata    14.0
# 3       Kolkata                       Eden Gardens, Kolkata     7.0
# 4        Mumbai                    Wankhede Stadium, Mumbai     5.0
# ..          ...                                         ...     ...
# 945     Kolkata                                Eden Gardens     5.0
# 946      Mumbai                            Wankhede Stadium     5.0
# 947       Delhi                            Feroz Shah Kotla     9.0
# 948  Chandigarh  Punjab Cricket Association Stadium, Mohali    33.0
# 949   Bangalore                       M Chinnaswamy Stadium   140.0
#
# [950 rows x 3 columns]

# %%
## Now how to fetch single rows - here in the case of this movie , it will tell about all the details oof the moves
movies.iloc[1]
# Out:
# title_x                                                 Battalion 609
# imdb_id                                                     tt9472208
# poster_path                                                       NaN
# wiki_link                 https://en.wikipedia.org/wiki/Battalion_609
# title_y                                                 Battalion 609
# original_title                                          Battalion 609
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           131
# genres                                                            War
# imdb_rating                                                       4.1
# imdb_votes                                                         73
# story               The story revolves around a cricket match betw...
# ...

# %%
ipl.iloc[26]
# Out:
# ID                                                           1304094
# City                                                     Navi Mumbai
# Date                                                      2022-05-03
# Season                                                          2022
# MatchNumber                                                       48
# Team1                                                 Gujarat Titans
# Team2                                                   Punjab Kings
# Venue                             Dr DY Patil Sports Academy, Mumbai
# TossWinner                                            Gujarat Titans
# TossDecision                                                     bat
# SuperOver                                                          N
# WinningTeam                                             Punjab Kings
# WonBy                                                        Wickets
# Margin                                                           8.0
# ...

# %%
## multiple row - her we hve to put the rane from what place we wanted
movies.iloc[10:20]
# Out:
#                    title_x    imdb_id  \
# 10                  Amavas  tt8396186
# 11               Gully Boy  tt2395469
# 12               Hum Chaar  tt9319812
# 13           Total Dhamaal  tt7639372
# 14              Sonchiriya  tt8108200
# 15       Badla (2019 film)  tt8130968
# 16  Mard Ko Dard Nahi Hota  tt8055888
# 17            Hamid (film)  tt7527082
# 18       Photograph (film)  tt7778680
# 19               Risknamaa  tt9795264
#
#                                           poster_path  \
# 10  https://upload.wikimedia.org/wikipedia/en/thum...
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 12  https://upload.wikimedia.org/wikipedia/en/thum...
# 13  https://upload.wikimedia.org/wikipedia/en/thum...
# 14  https://upload.wikimedia.org/wikipedia/en/thum...
# 15  https://upload.wikimedia.org/wikipedia/en/0/0c...
# 16  https://upload.wikimedia.org/wikipedia/en/thum...
# 17  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl.iloc[30:36]
# Out:
#          ID         City        Date Season MatchNumber  \
# 30  1304090  Navi Mumbai  2022-04-30   2022          44
# 31  1304089       Mumbai  2022-04-30   2022          43
# 32  1304088         Pune  2022-04-29   2022          42
# 33  1304087       Mumbai  2022-04-28   2022          41
# 34  1304086       Mumbai  2022-04-27   2022          40
# 35  1304085         Pune  2022-04-26   2022          39
#
#                           Team1                        Team2  \
# 30             Rajasthan Royals               Mumbai Indians
# 31  Royal Challengers Bangalore               Gujarat Titans
# 32         Lucknow Super Giants                 Punjab Kings
# 33        Kolkata Knight Riders               Delhi Capitals
# 34          Sunrisers Hyderabad               Gujarat Titans
# 35             Rajasthan Royals  Royal Challengers Bangalore
#
#                                             Venue  \
# 30             Dr DY Patil Sports Academy, Mumbai
# ...

# %%
## multiple rows but in specific gap
ipl.iloc[60:80:2]
# Out:
#          ID     City        Date Season MatchNumber  \
# 60  1304060     Pune  2022-04-06   2022          14
# 62  1304058   Mumbai  2022-04-04   2022          12
# 64  1304056     Pune  2022-04-02   2022          10
# 66  1304054   Mumbai  2022-04-01   2022           8
# 68  1304052   Mumbai  2022-03-30   2022           6
# 70  1304050   Mumbai  2022-03-28   2022           4
# 72  1304048   Mumbai  2022-03-27   2022           2
# 74  1254117    Dubai  2021-10-15   2021       Final
# 76  1254115  Sharjah  2021-10-11   2021  Eliminator
# 78  1254101    Dubai  2021-10-08   2021          56
#
#                           Team1                        Team2  \
# 60               Mumbai Indians        Kolkata Knight Riders
# 62         Lucknow Super Giants          Sunrisers Hyderabad
# 64               Gujarat Titans               Delhi Capitals
# 66                 Punjab Kings        Kolkata Knight Riders
# 68        Kolkata Knight Riders  Royal Challengers Bangalore
# ...

# %%
## fetching the column using the 'loc' - it will give the detail according to the lable
ipl.loc[78]
# Out:
# ID                                                           1254101
# City                                                           Dubai
# Date                                                      2021-10-08
# Season                                                          2021
# MatchNumber                                                       56
# Team1                                                 Delhi Capitals
# Team2                                    Royal Challengers Bangalore
# Venue                            Dubai International Cricket Stadium
# TossWinner                               Royal Challengers Bangalore
# TossDecision                                                   field
# SuperOver                                                          N
# WinningTeam                              Royal Challengers Bangalore
# WonBy                                                        Wickets
# Margin                                                           7.0
# ...

# %%
movies.loc[2]
# Out:
# title_x                          The Accidental Prime Minister (film)
# imdb_id                                                     tt6986710
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/The_Accidental_P...
# title_y                                 The Accidental Prime Minister
# original_title                          The Accidental Prime Minister
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           112
# genres                                                Biography|Drama
# imdb_rating                                                       6.1
# imdb_votes                                                       5549
# story               Based on the memoir by Indian policy analyst S...
# ...

# %%
## Multile fetching using the 'loc'
ipl.loc[34:39]
# Out:
#          ID         City        Date Season MatchNumber  \
# 34  1304086       Mumbai  2022-04-27   2022          40
# 35  1304085         Pune  2022-04-26   2022          39
# 36  1304084       Mumbai  2022-04-25   2022          38
# 37  1304083       Mumbai  2022-04-24   2022          37
# 38  1304082       Mumbai  2022-04-23   2022          36
# 39  1304081  Navi Mumbai  2022-04-23   2022          35
#
#                           Team1                        Team2  \
# 34          Sunrisers Hyderabad               Gujarat Titans
# 35             Rajasthan Royals  Royal Challengers Bangalore
# 36                 Punjab Kings          Chennai Super Kings
# 37         Lucknow Super Giants               Mumbai Indians
# 38  Royal Challengers Bangalore          Sunrisers Hyderabad
# 39               Gujarat Titans        Kolkata Knight Riders
#
#                                             Venue  \
# 34                       Wankhede Stadium, Mumbai
# ...

# %%
## here main difference in loc and iloc is , loc will include the range value

# %%
movies.loc[35:89:5]
# Out:
#                            title_x     imdb_id  \
# 35            Khamoshi (2019 film)   tt8268972
# 40                 Super 30 (film)   tt7485048
# 45               Chicken Curry Law   tt7189494
# 50                  Mission Mangal   tt9248972
# 55             Pal Pal Dil Ke Paas   tt6978954
# 60              Yaaram (2019 film)  tt11007050
# 65              Bypass Road (film)   tt9176260
# 70       Keep Safe Distance (film)   tt8876008
# 75  Pati Patni Aur Woh (2019 film)   tt9680136
# 80                     Kaalakaandi   tt6102396
# 85             Union Leader (film)   tt6395306
#
#                                           poster_path  \
# 35  https://upload.wikimedia.org/wikipedia/en/e/ef...
# 40  https://upload.wikimedia.org/wikipedia/en/thum...
# 45  https://upload.wikimedia.org/wikipedia/en/thum...
# 50  https://upload.wikimedia.org/wikipedia/en/thum...
# 55  https://upload.wikimedia.org/wikipedia/en/thum...
# 60  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
 ## Fetching in both row and column then use the "iloc"

# %%
movies.iloc[0:20,3:6]  # [name the column you want : the name the row you want]
# Out:
#                                             wiki_link  \
# 0   https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1         https://en.wikipedia.org/wiki/Battalion_609
# 2   https://en.wikipedia.org/wiki/The_Accidental_P...
# 3       https://en.wikipedia.org/wiki/Why_Cheat_India
# 4       https://en.wikipedia.org/wiki/Evening_Shadows
# 5           https://en.wikipedia.org/wiki/Soni_(film)
# 6         https://en.wikipedia.org/wiki/Fraud_Saiyaan
# 7            https://en.wikipedia.org/wiki/Bombairiya
# 8   https://en.wikipedia.org/wiki/Manikarnika:_The...
# 9      https://en.wikipedia.org/wiki/Thackeray_(film)
# 10               https://en.wikipedia.org/wiki/Amavas
# 11            https://en.wikipedia.org/wiki/Gully_Boy
# 12            https://en.wikipedia.org/wiki/Hum_Chaar
# 13        https://en.wikipedia.org/wiki/Total_Dhamaal
# 14           https://en.wikipedia.org/wiki/Sonchiriya
# 15    https://en.wikipedia.org/wiki/Badla_(2019_film)
# ...

# %%
## fetching the rows and column usiig the "loc"
movies.loc[0:5,'title_x' : 'wiki_link']
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
# 5                           Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# ...

# %%
## Find all the winners
mask = ipl['MatchNumber'] == 'Final'
ipl[mask]
new_df = ipl[mask]
new_df[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
ipl[ipl['MatchNumber'] == 'Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
## how many Super iver finishes have occured
ipl[ipl['SuperOver'] == 'Y'].shape
# Out:
# (14, 20)

# %%
ipl[ipl['SuperOver'] == 'Y'].shape[0]  #for getting 14 only
# Out:
# 14

# %%
## How many CSK Won in city Kolkata
ipl[ipl['City'] == 'Kolkata']
# Out:
#           ID     City        Date   Season  MatchNumber  \
# 2    1312198  Kolkata  2022-05-25     2022   Eliminator
# 3    1312197  Kolkata  2022-05-24     2022  Qualifier 1
# 207  1178422  Kolkata  2019-04-28     2019           47
# 211  1178418  Kolkata  2019-04-25     2019           43
# 219  1178410  Kolkata  2019-04-19     2019           35
# ..       ...      ...         ...      ...          ...
# 908   336025  Kolkata  2008-05-18  2007/08           41
# 915   336017  Kolkata  2008-05-13  2007/08           35
# 922   336010  Kolkata  2008-05-08  2007/08           29
# 934   335997  Kolkata  2008-04-29  2007/08           16
# 945   335986  Kolkata  2008-04-20  2007/08            4
#
#                            Team1                        Team2  \
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 207        Kolkata Knight Riders               Mumbai Indians
# ...

# %%
ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')]
# Out:
#           ID     City        Date   Season MatchNumber                  Team1  \
# 224  1178404  Kolkata  2019-04-14     2019          29  Kolkata Knight Riders
# 602   598022  Kolkata  2013-04-20     2013          26  Kolkata Knight Riders
# 641   548368  Kolkata  2012-05-14     2012          63  Kolkata Knight Riders
# 827   419113  Kolkata  2010-03-16  2009/10           8  Kolkata Knight Riders
# 908   336025  Kolkata  2008-05-18  2007/08          41  Kolkata Knight Riders
#
#                    Team2         Venue             TossWinner TossDecision  \
# 224  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 602  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
# 641  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 827  Chennai Super Kings  Eden Gardens    Chennai Super Kings          bat
# 908  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
#
# ...

# %%
ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
# Toss winner is the match winner pecentage
toss_winner_and_match_winnercount = ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]
toss_winner_and_match_winnercount
# Out:
# 489

# %%
toss_winner = ipl['TossWinner'].shape[0]
toss_winner
# Out:
# 950

# %%
(toss_winner_and_match_winnercount / toss_winner) * 100
# Out:
# 51.473684210526315

# %%
## movies with rating higher than 8 and votes > 10000
movies[(movies['imdb_rating']>8) & (movies['imdb_votes']>10000)]
# Out:
#                           title_x     imdb_id  \
# 0        Uri: The Surgical Strike   tt8291224
# 11                      Gully Boy   tt2395469
# 37              Article 15 (film)  tt10324144
# 40                Super 30 (film)   tt7485048
# 143                       Tumbbad   tt8239946
# 146                     Andhadhun   tt8108198
# 325              Pink (2016 film)   tt5571734
# 354                 Dangal (film)   tt5074352
# 418                        Masaan   tt4635372
# 426          Drishyam (2015 film)   tt4430212
# 436                 Talvar (film)   tt4934950
# 469             Queen (2014 film)   tt3322420
# 536                 Haider (film)   tt3390572
# 566                   Ugly (film)   tt2882328
# 567                     PK (film)   tt2338151
# 589                  Vishwaroopam   tt2199711
# 612            Bhaag Milkha Bhaag   tt2356180
# 638                 Shahid (film)   tt2181831
# 668       Paan Singh Tomar (film)   tt1620933
# ...

# %%
movies['imdb_rating']
# Out:
# 0       8.4
# 1       4.1
# 2       6.1
# 3       6.0
# 4       7.3
#        ...
# 1624    4.9
# 1625    3.0
# 1626    6.1
# 1627    7.4
# 1628    9.0
# Name: imdb_rating, Length: 1629, dtype: float64

# %%
## Action movies with rating higer that 7.5
movies['genres'].str

# %%
mask1 = movies['genres'].str.split('|').apply(lambda x: 'Romance' in x)

# %%
mask2 = movies['imdb_rating'] > 7.5
mask2
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627    False
# 1628     True
# Name: imdb_rating, Length: 1629, dtype: bool

# %%
movies[mask1 & mask2]
# Out:
#                         title_x     imdb_id  \
# 57       P Se Pyaar F Se Faraar  tt10816510
# 129     Laila Majnu (2018 film)   tt8011276
# 241     Shaadi Mein Zaroor Aana   tt7469726
# 275               Kapoor & Sons   tt4900716
# 347                Dear Zindagi   tt5946128
# 357     Tanu Weds Manu: Returns   tt2140465
# 358     Tanu Weds Manu: Returns   tt2140465
# 465   Highway (2014 Hindi film)   tt2980794
# 582                Bloody Isshq   tt2404187
# 606                  Raanjhanaa   tt2359810
# 635                The Lunchbox   tt2350496
# 678                 Vicky Donor   tt2317337
# 709                      Barfi!   tt2082197
# 770          Pyaar Ka Punchnama   tt1926313
# 847           The Japanese Wife   tt1620620
# 960                 Wake Up Sid   tt1324059
# 1087                 Jab We Met   tt1093370
# 1183       Lage Raho Munna Bhai   tt0456144
# 1361             Lakshya (film)   tt0323013
# 1378            Raincoat (film)   tt0405266
# ...

# %%
mz = movies[mask1 & mask2]
mz['title_x']
# Out:
# 57         P Se Pyaar F Se Faraar
# 129       Laila Majnu (2018 film)
# 241       Shaadi Mein Zaroor Aana
# 275                 Kapoor & Sons
# 347                  Dear Zindagi
# 357       Tanu Weds Manu: Returns
# 358       Tanu Weds Manu: Returns
# 465     Highway (2014 Hindi film)
# 582                  Bloody Isshq
# 606                    Raanjhanaa
# 635                  The Lunchbox
# 678                   Vicky Donor
# 709                        Barfi!
# 770            Pyaar Ka Punchnama
# 847             The Japanese Wife
# 960                   Wake Up Sid
# 1087                   Jab We Met
# 1183         Lage Raho Munna Bhai
# 1361               Lakshya (film)
# 1378              Raincoat (film)
# 1395                Kal Ho Naa Ho
# 1434                       Haasil
# 1490     Devdas (2002 Hindi film)
# 1571               Dil Chahta Hai
# 1628                     Humsafar
# Name: title_x, dtype: object
